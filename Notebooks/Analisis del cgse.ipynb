# %% [markdown]
# Auditoria gran encuesta integrada de hogares

# %% [markdown]
# 4 modulos
# -CGSE
# -FT
# -OCUPADOS
# -DESEMPLEADOS

# %% [markdown]
# Leyendo la tabla de caracteristicas generales

# %%
cgse = spark.read.format("delta").table("workspace.electiva.cgse")

# %%
cgse.display()

# %% [markdown]
# Se dene utilizar el diccionario del dane para saber como se llaman las filas y columnas, esto facilitara mucho el analisis ya que los nombres vienen codificados

# %% [markdown]
# Convertir el DataFrame de Spark a Pandas

# %%
cgse = cgse.toPandas()

# %%
cgse
